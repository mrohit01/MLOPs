# %% [markdown]
# # <u>MLOPs</u>

# %%
MLops = ML model [ml/dl/nlp] + DevOps + Drift/Retraining

# %%
e.g. 

IPL >> Dream11 [fantasy gaming] , feb - may [user beheviour]


ind - IRL tour >> Dream11 >> [data features got changed]

whatever performance changed in this process >> Drift [Evidently AI tool to monitor the drifting]

Create new dataset : model retraining

# %% [markdown]
# ![image.png](attachment:c88cdc45-9fbf-43de-90d8-2ba02729e8f6.png)

# %%
Data Scientist : Machine Learning Model[ml/dl/nlp] + Software engg [programming, web framework, database]
Data Engineer: 

Mlops: cloud[AWS/GCP/Azure] + ds + se

Job Resposiblities: 
>> Automating ml model deployment. 
>> Setting Monitoring  ML pipeline. 
>> CI/CD pipeline [data,code, model] setup. 
>> Automate the model retraining. 
>> Decide the what resources[cloud]. 


AWS cloud.

# %%
Git >> Advance 
github , aws codecommit
CI/CD >> Github actions, jenkins 
git vs github 


Docker >> 


Kubernetes >>


AWS >> 

AWS Sagemaker[notebook, studio]

Monitoring : Drift , retraining.

# %%
DATA SCIENCE Project 

1. Probelm Statement 

8. Deployment []
9. monitoring + Retraining

# %%
ML : Python, ML Algo, Flask, domain 
tools : git, 
devops : docker and kubernates 
experiement tracking : mlflow
cloud : AWS[GCP/Azure]

# %% [markdown]
# # Git

# %%
git 
URL: https://git-scm.com/download/win

VCS >> Version Control System. 

Code Changes Tracking, Who done changes , collabrative [Distributes.]

# %%
VCS >> Version Control System. 
1. Distributed : git [github, bitbucket, gitlab]
2. Centralised : SVN [turtle svn]

# %% [raw]
# Centralized Version Control System (CVCS): CVCS involves a central server that stores the entire history of the project. Developers check out files from this central repository to work on them and then commit changes back to the server.
#
# Distributed Version Control System (DVCS): DVCS allows multiple developers to work on a project simultaneously and independently. Each developer has a local repository that contains the full history of the project.

# %% [raw]
# Centralized and decentralized version control systems (VCS) are two different approaches to managing and tracking changes in software development projects. They have distinct characteristics and advantages, and the choice between them often depends on the specific needs and preferences of a development team. Here are the key differences between centralized and decentralized version control systems:
#
# Repository Location:
#
# Centralized VCS: In a centralized VCS, there is a single, central repository that stores the entire history of the project. Developers clone a copy of this repository to their local machines, make changes, and then commit those changes back to the central repository.
#
# Decentralized VCS: In a decentralized VCS, each developer has their own local repository that contains the full history of the project. Developers can work independently on their local repositories, and changes can be synchronized between repositories as needed.
#
# Network Dependency:
#
# Centralized VCS: Requires a constant network connection to the central repository. Developers need network access to commit changes, view project history, or collaborate with others.
#
# Decentralized VCS: Developers can work offline because they have a local copy of the entire repository history. Network access is only required when pushing changes to or pulling changes from remote repositories.
#
# Branching and Merging:
#
# Centralized VCS: Branching and merging can be more complex in centralized VCS systems. Typically, there is a main trunk or branch, and developers create separate branches for their work. Merging changes back into the main branch can sometimes be challenging.
#
# Decentralized VCS: Branching and merging are often easier and more flexible in decentralized VCS systems. Developers can create branches and merge them with relative ease, as they have their own local repository.
#
# Collaboration:
#
# Centralized VCS: Collaboration is often more controlled and centralized. Developers must coordinate their changes through the central repository, which can lead to conflicts and delays if not managed properly.
#
# Decentralized VCS: Collaboration can be more distributed and flexible. Developers can work independently on their local repositories and merge changes when they are ready. This can lead to smoother parallel development.
#
# Backup and Redundancy:
#
# Centralized VCS: The central repository serves as a single point of failure. If it becomes corrupted or unavailable, it can disrupt the entire development process.
#
# Decentralized VCS: Multiple copies of the repository exist on developers' machines, providing redundancy and reducing the risk of data loss.

# %%
Task to do: 

1. git install on local 
2. configure git 
    git config --global user.name "your user_name"
    git config --global user.email "user_email@domain.com"

# %% [raw]
# "Dev environment," "UAT environment," and "production environment" are terms commonly used in software development and deployment to describe different stages or environments in the software development lifecycle.
#
# Development Environment (Dev):
# Purpose: This environment is where software developers and engineers work on coding, testing, and debugging new features or changes to an application.
# Characteristics:
#     Typically located on developers' local machines or dedicated development servers.
#     Contains the latest code changes that may not be stable or complete.
#     May use mock data or test databases.
#     Debugging tools and development libraries are readily available.
#     Changes can be made frequently without affecting the production system.
#
# User Acceptance Testing Environment (UAT):
# Purpose: UAT is used for testing the software's functionality and usability from an end-user perspective before deploying it to production.
# Characteristics:
#     Often a replica of the production environment in terms of infrastructure and configuration.
#     Contains the latest stable version of the software.
#     Realistic test data and configurations are used.
#     Testing is carried out by internal or external users to ensure the software meets business requirements.
#     Typically used for final validation and feedback before production deployment.
#
# Staging Environment:
# A replica of the production environment used for final testing before deploying new features or updates.
# Helps identify and resolve issues that may not surface in the development or testing environments.
#
#
# Production Environment (Prod):
# Purpose: Production is the live environment where the software is actively used by end-users or customers.
# Characteristics:
#     Hosts the official, stable, and fully-tested version of the software.
#     Contains real data and configurations.
#     High availability, scalability, and performance are critical.
#     Monitoring and security measures are in place to ensure system stability.
#     Any changes introduced must go through a rigorous change management process.
